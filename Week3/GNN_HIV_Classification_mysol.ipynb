# %% [markdown]
# # HIV-Inhibiting Molecule Classification using Deep Learning

# %% [markdown]
# ## Roadmap
#
# 1. Introduce the problem and the dataset
# 2. Import libraries
# 3. Load the data
# 4. Visualize the data
# 5. Visualize the metrics that need to be achieved
# 6. Try logistic regression
# 7. Try a simple neural network
# 8. Try a simple GCN
# 9. Try a simple GAT
# 10. Try playing with convolution and aggregation styles

# %% [markdown]
# ## Install Instructions

# %%
# Assuming you have a conda env already set up
# !pip install -r requirements.txt

# %%
# This next install depends on whether you have a cpu or gpu. If you have a gpu, you can install the gpu version of torch_geometric:
# !pip install torch_scatter -f https://data.pyg.org/whl/torch-2.3.0+cu121.html
# If you have a cpu, comment out the above line and run the following command:
#!pip install torch_scatter -f https://data.pyg.org/whl/torch-2.3.0+cpu.html

# %%
# !pip install --force-reinstall torch_scatter -f https://data.pyg.org/whl/torch-2.3.0+cpu.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.3.0+cpu.html
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.3.0%2Bcpu/torch_scatter-2.1.2%2Bpt23cpu-cp311-cp311-linux_x86_64.whl (515 kB)
#      l     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/515.4 kB ? eta -:--:--━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 368.6/515.4 kB 11.5 MB/s eta 0:00:01━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 512.0/515.4 kB 12.2 MB/s eta 0:00:01━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.4/515.4 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: torch_scatter
#   Attempting uninstall: torch_scatter
#     Found existing installation: torch_scatter 2.1.2+pt23cu121
#     Uninstalling torch_scatter-2.1.2+pt23cu121:
#       Successfully uninstalled torch_scatter-2.1.2+pt23cu121
# Successfully installed torch_scatter-2.1.2+pt23cpu

# %% [markdown]
# ## Intro

# %% [markdown]
# The nodes in the graph have features given by `graph.x`:
# - atomic_num: the atomic number of the atom
# - chirality: the chirality of the atom
# - degree: the degree of the atom
# - formal_charge: the formal charge of the atom
# - num_h: the number of hydrogens of the atom
# - num_rad_e: the number of radical electrons of the atom
# - hybridization: the hybridization of the atom
# - is_aromatic: whether the atom is aromatic
# - is_in_ring: whether the atom is in a ring
#
# The edges in the graph have features given by `graph.edge_attr`:
# - bond_type: the type of the bond
# - bond_stereo: the stereo of the bond
# - is_conjugated: whether the bond is conjugated
#
# The graph has just one "feature", which is a binary label indicating whether the molecule is an HIV-inhibitor or not:
# - `graph.y`: whether the molecule is an HIV-inhibitor

# %% [markdown]
# ## Load the data

# %%
from ogb.graphproppred import PygGraphPropPredDataset
from torch_geometric.data import DataLoader

dataset = PygGraphPropPredDataset(name = "ogbg-molhiv") 

split_idx = dataset.get_idx_split() 
train_pyg_loader = DataLoader(dataset[split_idx["train"]], batch_size=32, shuffle=True)
valid_pyg_loader = DataLoader(dataset[split_idx["valid"]], batch_size=32, shuffle=False)
test_pyg_loader = DataLoader(dataset[split_idx["test"]], batch_size=32, shuffle=False)
# Out:
# /home/ali/miniconda3/lib/python3.11/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %% [markdown]
# ## Visualize the data

# %%
example_graph = valid_pyg_loader.dataset[0]
print(example_graph)
# Out:
# Data(edge_index=[2, 52], edge_attr=[52, 3], x=[23, 9], y=[1, 1], num_nodes=23)

# %%
import networkx as nx
from torch_geometric.utils import to_networkx

# %%
import matplotlib.pyplot as plt
# Function to visualize graph based on target value
def visualize_graph_with_target(loader, target_value):
    for graph in loader.dataset:
        if graph.y.item() == target_value:
            plt.figure(figsize=(10, 10))
            atomic_number = graph.x[:, 0].numpy()
            graph_networkx = to_networkx(graph.clone())
            pos = nx.spring_layout(graph_networkx)
            nx.draw_networkx(graph_networkx, pos, labels=dict(zip(range(len(atomic_number)), atomic_number)), node_size=300, node_color=atomic_number, cmap="tab20")
            plt.title(f"Graph with target {graph.y.item()}")
            plt.show()
            break

# Visualize graph with target 0
visualize_graph_with_target(valid_pyg_loader, 0)

# Visualize graph with target 1
visualize_graph_with_target(valid_pyg_loader, 1)

# %%
# Plot histograms of graph sizes for true and false graphs
import seaborn as sns
import pandas as pd

def plot_histograms_of_graph_sizes(loader):
    true_sizes = []
    false_sizes = []
    for graph in loader.dataset:
        if graph.y.item() == 1:
            true_sizes.append(graph.num_nodes)
        else:
            false_sizes.append(graph.num_nodes)
    
    # Create a DataFrame to facilitate plotting with seaborn
    data_true = pd.DataFrame({'Size': true_sizes, 'Target': 'True'})
    data_false = pd.DataFrame({'Size': false_sizes, 'Target': 'False'})
    data = pd.concat([data_true, data_false])
    
    # Plotting the histograms
    plt.figure(figsize=(10, 6))
    sns.histplot(data, x='Size', hue='Target', element='step', kde=True, palette=['green', 'red'])
    plt.title('Histogram of Graph Sizes for True and False Targets')
    plt.xlabel('Graph Size')
    plt.ylabel('Count')
    plt.show()

plot_histograms_of_graph_sizes(valid_pyg_loader)

# %% [markdown]
# We see that the data is VERY imbalanced - most molecules are not useful for fighting HIV (as you might expect!). So we will need to be careful about how we evaluate our models. We can't simply use accuracy, as a model that always predicts "not an HIV-inhibitor" would be right 99% of the time!

# %%
# Let's also histogram each of the node features, so we know what scales they are:
def plot_histograms_of_node_features(loader):
    feature_names = ['atomic_num', 'chirality', 'degree', 'formal_charge', 'num_h', 'num_rad_e', 'hybridization', 'is_aromatic', 'is_in_ring']
    num_features = len(feature_names)
    
    # Create a 3x3 subplot grid
    fig, axes = plt.subplots(3, 3, figsize=(15, 15))
    axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easier iteration
    
    for i in range(num_features):
        all_features = []
        for graph in loader.dataset:
            all_features.extend(graph.x[:, i].numpy())
        
        # Plot on the ith subplot
        sns.histplot(all_features, element='step', ax=axes[i])
        axes[i].set_title(f'Histogram of {feature_names[i]}')
        axes[i].set_xlabel(f'{feature_names[i]} Value')
        axes[i].set_ylabel('Count')
        axes[i].set_yscale('log')  # Set y-axis scale to logarithmic
    
    # Adjust layout to prevent overlap
    plt.tight_layout()
    plt.show()

plot_histograms_of_node_features(valid_pyg_loader)

# %% [markdown]
# Overall, the data is all of a similar scale, so we don't need to be too worried about normalizing. Maybe we could take the log of the atomic number, and add that as a feature. But that's about it.

# %% [markdown]
# ## Try Logistic Regression

# %% [markdown]
# Let's try the absolute most naive thing: Logistic regression. This will give us a baseline to compare against.
# The first question is what is the input to our logistic regression. It's non-obvious, since we have two problems:
# 1. The input features are nodes in no obvious or particular order
# 2. The list of nodes is different from one graph to the next
#
# So to make our first naive benchmark as simple as possible, let's take some simplifications to the dataset:
# 1. Let's sort the nodes from largest to smallest atomic number
# 2. Let's take the first 10 sorted nodes in each graph, and pad with zeros if there are fewer than 20 nodes

# %% [markdown]
# ### Sort the nodes by atomic number

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

# Function to preprocess and flatten graph data
def preprocess_data(loader):
    X, y = [], []
    for data in loader.dataset:
        # Sort nodes by atomic number in descending order
        node_features = data.x
        sorted_nodes = node_features[node_features[:, 0].argsort(descending=True)]
        
        # Add log of the first feature (atomic number) as a new feature
        log_feature = np.log(sorted_nodes[:, 0] + 1).reshape(-1, 1)  # Adding 1 to avoid log(0)
        sorted_nodes = np.hstack([sorted_nodes, log_feature])
        
        # Select the first N nodes
        num_nodes = 20

        # Select the first 20 nodes, pad if necessary
        if len(sorted_nodes) < num_nodes:
            padding = np.zeros((num_nodes - len(sorted_nodes), sorted_nodes.shape[1]))
            sorted_nodes = np.vstack([sorted_nodes, padding])
        elif len(sorted_nodes) > num_nodes:
            sorted_nodes = sorted_nodes[:num_nodes]
        
        # Flatten the node features to create a single feature vector
        flat_features = sorted_nodes.flatten()
        X.append(flat_features)
        y.append(data.y.item())
    
    return np.array(X), np.array(y)

# %%
# Preprocess the data
X_train, y_train = preprocess_data(train_pyg_loader)
X_valid, y_valid = preprocess_data(valid_pyg_loader)
X_test, y_test = preprocess_data(test_pyg_loader)

# %%
# Train logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Evaluate the model
y_pred_valid = model.predict(X_valid)
y_pred_test = model.predict(X_test)
valid_accuracy = accuracy_score(y_valid, y_pred_valid)
valid_auc = roc_auc_score(y_valid, model.predict_proba(X_valid)[:, 1])
test_accuracy = accuracy_score(y_test, y_pred_test)
test_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])

print(f"Validation Accuracy: {valid_accuracy}")
print(f"Validation AUC: {valid_auc}")

print(f"Test Accuracy: {test_accuracy}")
print(f"Test AUC: {test_auc}")

# Also get the ROC AUC for a random classifier
random_preds = np.random.rand(len(y_test))
random_auc = roc_auc_score(y_test, random_preds)

fpr_valid, tpr_valid, _ = roc_curve(y_valid, model.predict_proba(X_valid)[:, 1])
fpr_test, tpr_test, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
plt.figure(figsize=(10, 6))
plt.plot(fpr_valid, tpr_valid, label='Validation')
plt.plot(fpr_test, tpr_test, label='Test')
plt.plot([0, 1], [0, 1], linestyle='--', color='black')
plt.text(0.7, 0.3, f'Valid AUC: {valid_auc:.2f}', fontsize=12)
plt.text(0.7, 0.2, f'Test AUC: {test_auc:.2f}', fontsize=12)
plt.text(0.7, 0.1, f'Random AUC: {random_auc:.2f}', fontsize=12)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression')
plt.legend()
plt.show()
# Out:
# Validation Accuracy: 0.9786044249939218
# Validation AUC: 0.7086931094454243
# Test Accuracy: 0.9683929005592026
# Test AUC: 0.6824851773885167
# /home/ali/miniconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Okay, we're better than a coin flip. Not bad for 3 seconds of work. But we have a long way to go if we want to get onto the OGB Leaderboard for this benchmark:
# ![OGB Leaderboard](img/mol_hiv_leaderboard.png)
#
# So let's try something more sophisticated...

# %% [markdown]
# ## Try a BDT

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Train Gradient Boosting model
bdt_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
bdt_model.fit(X_train, y_train)

# Evaluate the model using AUC
y_prob_valid_bdt = bdt_model.predict_proba(X_valid)[:, 1]  # Get probabilities for the positive class
y_prob_test_bdt = bdt_model.predict_proba(X_test)[:, 1]    # Get probabilities for the positive class

valid_auc_bdt = roc_auc_score(y_valid, y_prob_valid_bdt)
test_auc_bdt = roc_auc_score(y_test, y_prob_test_bdt)

print(f"Validation AUC (BDT): {valid_auc_bdt}")
print(f"Test AUC (BDT): {test_auc_bdt}")

# Plot ROC curve
fpr_valid_bdt, tpr_valid_bdt, _ = roc_curve(y_valid, y_prob_valid_bdt)
fpr_test_bdt, tpr_test_bdt, _ = roc_curve(y_test, y_prob_test_bdt)

plt.figure(figsize=(10, 6))
plt.plot(fpr_valid_bdt, tpr_valid_bdt, label='Validation (BDT)')
plt.plot(fpr_test_bdt, tpr_test_bdt, label='Test (BDT)')
plt.plot(fpr_valid, tpr_valid, label='Validation (LR)')
plt.plot([0, 1], [0, 1], linestyle='--', color='black')
plt.text(0.7, 0.3, f'Validation AUC (BDT): {valid_auc_bdt:.2f}', fontsize=12)
plt.text(0.7, 0.2, f'Test AUC (BDT): {test_auc_bdt:.2f}', fontsize=12)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# Out:
# Validation AUC (BDT): 0.7357176538310797
# Test AUC (BDT): 0.7265851020684061

# %% [markdown]
# Creeping up... but still a long way to go to an AUC of 0.84. Let's try a simple neural network next.

# %% [markdown]
# ## Try a simple neural network

# %% [markdown]
# For this simple neural network, let's switch back to pytorch. In particular, let's use pytorch lightning to avoid boilerplate code. (If you haven't used pytorch or pytorch lightning before, you can think of pytorch = tensorboard, and pytorch lightning = keras).

# %%
import lightning as lit
from lightning.pytorch.callbacks import Callback
from lightning.pytorch import Trainer
from torch.utils.data import TensorDataset, DataLoader
import torch
from torch import nn
from lightning.pytorch.loggers import CSVLogger  # Import CSVLogger
import numpy as np

def prepare_data_loaders(X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=32):
    train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    valid_dataset = TensorDataset(torch.FloatTensor(X_valid), torch.FloatTensor(y_valid))
    test_dataset = TensorDataset(torch.FloatTensor(X_test), torch.FloatTensor(y_test))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, valid_loader, test_loader

def make_mlp(
    input_size,
    sizes,
    hidden_activation="ReLU",
    output_activation=None,
    layer_norm=False,
):
    """Construct an MLP with specified fully-connected layers."""
    hidden_activation = getattr(nn, hidden_activation)()
    output_activation = getattr(nn, output_activation)() if output_activation else None
    layers = []
    sizes = [input_size] + sizes

    # Add hidden layers
    for i in range(len(sizes) - 2):  # Change the range to stop before the last hidden layer
        layers.append(nn.Linear(sizes[i], sizes[i + 1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i + 1], elementwise_affine=False))
        layers.append(hidden_activation)

    # Add final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation:
        layers.append(output_activation)

    return nn.Sequential(*layers)

class BaseLitModel(lit.LightningModule):
    def __init__(self, lr=1e-3, weight_decay=0, lr_decay=0.95):
        super().__init__()

        self.criterion = nn.BCELoss()
        self.val_preds = []
        self.val_targets = []
        self.test_preds = []
        self.test_targets = []
        self.lr = lr
        self.weight_decay = weight_decay
        self.lr_decay = lr_decay

    def training_step(self, batch, batch_idx):
        y_hat, y = self.apply_model(batch)
        # Check if y needs to be unsqueezed
        if len(y.shape) == 1:
            y = y.unsqueeze(1)
        loss = self.criterion(y_hat, y.float())
        self.log('train_loss', loss, on_step=False, on_epoch=True, prog_bar=True)  # Log on progress bar
        self.log('learning_rate', self.trainer.optimizers[0].param_groups[0]['lr'], on_step=False, on_epoch=True, prog_bar=True)  # Log current learning rate
        return loss

    def validation_step(self, batch, batch_idx):
        y_hat, y = self.apply_model(batch)
        # Check if y needs to be unsqueezed
        if len(y.shape) == 1:
            y = y.unsqueeze(1)
        loss = self.criterion(y_hat, y.float())
        self.log('val_loss', loss, on_epoch=True, prog_bar=True)  # Log on progress bar
        self.val_preds.extend(y_hat.view(-1).detach().cpu().numpy())
        self.val_targets.extend(y.view(-1).detach().cpu().numpy())
        return loss
    
    def test_step(self, batch, batch_idx):
        y_hat, y = self.apply_model(batch)
        # Check if y needs to be unsqueezed
        if len(y.shape) == 1:
            y = y.unsqueeze(1)
        loss = self.criterion(y_hat, y.float())
        self.log('test_loss', loss, on_epoch=True, prog_bar=True)  # Log on progress bar
        self.test_preds.extend(y_hat.view(-1).detach().cpu().numpy())
        self.test_targets.extend(y.view(-1).detach().cpu().numpy())
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.lr, weight_decay=self.weight_decay)
        lr_scheduler = {
            'scheduler': torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: self.lr_decay ** epoch),
            'name': 'lambda_decay'
        }
        return [optimizer], [lr_scheduler]

class AUCCallback(Callback):
    def on_validation_epoch_end(self, trainer, pl_module):
        val_auc = roc_auc_score(pl_module.val_targets, pl_module.val_preds)
        pl_module.log("val_auc", val_auc, prog_bar=True)  # Log on progress bar
        pl_module.val_preds = []
        pl_module.val_targets = []

    def on_test_epoch_end(self, trainer, pl_module):
        test_auc = roc_auc_score(pl_module.test_targets, pl_module.test_preds)
        pl_module.log("test_auc", test_auc, prog_bar=True)  # Log on progress bar
        pl_module.test_preds = []
        pl_module.test_targets = []

# Prepare data loaders
def prepare_data_loaders(X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=32):
    train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    valid_dataset = TensorDataset(torch.FloatTensor(X_valid), torch.FloatTensor(y_valid))
    test_dataset = TensorDataset(torch.FloatTensor(X_test), torch.FloatTensor(y_test))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, valid_loader, test_loader

# %%
class SimpleMLP(BaseLitModel):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleMLP, self).__init__(lr=1e-3, weight_decay=0, lr_decay=0.90)
        self.model = make_mlp(input_size, 
                              [hidden_size]*3 + [output_size],
                              hidden_activation="ReLU", 
                              layer_norm=True,
                              output_activation="Sigmoid")

    def forward(self, x):
        return self.model(x)

    def apply_model(self, batch):
        x, y = batch
        return self(x), y
        
# Data loaders
train_loader, valid_loader, test_loader = prepare_data_loaders(X_train, y_train, X_valid, y_valid, X_test, y_test)

# Initialize the model
input_size = train_loader.dataset[0][0].shape[0]  # Adjust input size for the new feature
hidden_size = 64  # You can tune this parameter
output_size = 1
model = SimpleMLP(input_size, hidden_size, output_size)

# Train the model
auc_callback = AUCCallback()
csv_logger = CSVLogger('lightning_logs', name='mlp_model')  # Initialize CSVLogger
trainer = Trainer(max_epochs=10, accelerator="gpu", callbacks=[auc_callback], logger=csv_logger)  # Add logger to Trainer
trainer.fit(model, train_loader, valid_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | BCELoss    | 0
# 1 | model     | Sequential | 21.2 K
# -----------------------------------------
# 21.2 K    Trainable params
# 0         Non-trainable params
# 21.2 K    Total params
# 0.085     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 1029/1029 [00:08<00:00, 117.26it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 129.04it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 140.03it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 157.62it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 169.47it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 171.02it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 168.66it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 169.27it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 167.15it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 163.56it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 163.30it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 165.15it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 167.08it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 170.75it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 173.35it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 173.59it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 177.11it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 178.30it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 179.68it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 178.76it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 179.42it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 181.62it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 179.27it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 178.35it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 177.50it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 176.58it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 177.81it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 177.98it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 178.66it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 179.35it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 181.40it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 183.55it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 185.01it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 184.04it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 183.38it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 183.57it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 183.62it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 184.15it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 185.27it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 186.72it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 187.82it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 188.68it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 189.48it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 189.38it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 187.47it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 187.28it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 187.19it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 186.57it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 186.84it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 187.09it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 188.16it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 189.30it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 190.05it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 189.96it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 190.09it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 190.90it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 191.27it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 191.38it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 191.88it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 192.52it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 192.52it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 192.00it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 192.34it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 192.51it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 191.12it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 191.87it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 191.82it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 191.29it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 191.62it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 192.28it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 192.33it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 192.90it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 193.22it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 193.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 193.76it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 194.43it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 194.80it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 195.33it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 195.33it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 195.86it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 196.52it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 196.85it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 196.73it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 197.19it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 197.75it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 198.13it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 198.72it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 199.27it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 199.65it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 199.91it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 199.65it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 200.09it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 200.36it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 200.38it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 200.52it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 200.93it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 201.35it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 201.64it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 201.97it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 202.32it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 202.16it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 202.12it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 202.48it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 202.62it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 202.83it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 203.33it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 203.79it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 204.27it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 204.10it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 204.08it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 204.27it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 204.52it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 203.95it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 204.11it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 204.12it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 203.65it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 203.76it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 203.95it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 204.10it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 204.20it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 204.53it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 204.21it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 203.93it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 204.12it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 204.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 203.86it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 203.85it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 204.23it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 204.13it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 204.18it/s]
# Epoch 1: 100%|██████████| 1029/1029 [00:06<00:00, 157.53it/s, v_num=1, val_loss=0.0946, val_auc=0.695, train_loss=0.157, learning_rate=0.001]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 212.38it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 219.40it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 252.32it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 270.67it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 287.83it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 292.50it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 287.55it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 294.38it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 301.86it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 308.97it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 314.38it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 307.18it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 304.68it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 306.62it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 309.39it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 312.51it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 313.49it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 310.85it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 312.48it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 314.24it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 316.85it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 318.56it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 311.73it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 312.71it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 313.46it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 312.32it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 314.24it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 314.93it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 312.62it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 313.81it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 314.63it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 316.55it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 316.09it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 314.60it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 316.51it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 318.30it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 318.31it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 319.10it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 318.03it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 317.28it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 318.26it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 319.64it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 319.99it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 319.79it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 317.85it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 319.03it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 320.33it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 319.50it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 318.95it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 316.79it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00,
/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 276.21it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 276.79it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 276.32it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 276.73it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 277.13it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 276.91it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 277.32it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 277.70it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 277.97it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 278.30it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 278.08it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 278.13it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 278.53it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 278.90it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 279.14it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 278.67it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 278.52it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 278.95it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 279.12it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 279.24it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 278.92it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 278.87it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 279.33it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 279.63it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 279.71it/s]
# Epoch 9: 100%|██████████| 1029/1029 [00:06<00:00, 152.92it/s, v_num=1, val_loss=0.0956, val_auc=0.695, train_loss=0.144, learning_rate=0.00043]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 174.76it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 242.52it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 276.50it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 298.85it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 316.47it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 301.94it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 305.97it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 314.04it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 301.20it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 307.75it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 297.48it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 298.52it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 304.92it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 299.29it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 305.37it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 294.46it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 295.79it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 294.10it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 292.22it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 287.59it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 287.45it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 288.63it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 290.17it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 290.34it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 287.37it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 286.96it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 286.98it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 287.27it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 288.12it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 285.60it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 286.84it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 287.68it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 288.70it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 289.03it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 284.29it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 279.87it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 276.03it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 274.50it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 276.11it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 277.50it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 278.84it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 279.91it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 276.56it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 277.79it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 278.77it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 278.06it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 275.96it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 276.40it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 277.57it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 278.50it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 278.92it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 277.75it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 279.20it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 280.86it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 282.13it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 283.64it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 285.04it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 283.23it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 284.45it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 285.37it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 286.19it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 287.31it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 286.02it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 287.19it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 288.20it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 289.48it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 290.20it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 291.04it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 289.90it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 291.09it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 292.09it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 292.22it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 293.41it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 293.11it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 293.36it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 294.41it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 295.37it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 296.41it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 297.43it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 296.85it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 297.53it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 298.27it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 298.52it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 299.03it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 299.80it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 298.62it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 299.54it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 299.98it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 300.45it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 301.35it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 300.81it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 301.07it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 301.63it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 302.18it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 302.92it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 303.51it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 302.65it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 303.34it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 303.53it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 304.09it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 304.66it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 305.03it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 304.25it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 304.26it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 304.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 305.17it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 305.60it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 304.42it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 304.77it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 305.26it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 305.66it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 305.99it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 305.30it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 305.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 306.37it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 306.84it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 307.24it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 307.44it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 306.56it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 307.02it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 307.62it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 308.25it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 308.88it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 309.32it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 308.96it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 309.63it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 310.22it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 310.80it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 311.47it/s]
# Epoch 9: 100%|██████████| 1029/1029 [00:07<00:00, 143.77it/s, v_num=1, val_loss=0.0971, val_auc=0.701, train_loss=0.143, learning_rate=0.000387]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 1029/1029 [00:07<00:00, 143.51it/s, v_num=1, val_loss=0.0971, val_auc=0.701, train_loss=0.143, learning_rate=0.000387]

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

def find_latest_directory(base_path):
    list_of_files = glob.glob(f'{base_path}/version_*')
    latest_dir = max(list_of_files, key=os.path.getmtime)
    return latest_dir

def plot_metrics(directory, model_name):
    metrics_file = os.path.join(directory, 'metrics.csv')
    metrics_df = pd.read_csv(metrics_file)
    train_loss_df = metrics_df[metrics_df['train_loss'].notna()]
    val_loss_df = metrics_df[metrics_df['val_loss'].notna()]
    val_auc_df = metrics_df[metrics_df['val_auc'].notna()]
    learning_rate_df = metrics_df[metrics_df['learning_rate'].notna()]  # Extract learning rate data

    plt.figure(figsize=(16, 4))  # Adjusted figure size to accommodate new subplot
    plt.subplot(1, 4, 1)
    plt.plot(train_loss_df['step'], train_loss_df['train_loss'], label='Training Loss')
    plt.title('Training Loss Over Epochs')
    plt.xlabel('Step')
    plt.ylabel('Loss')
    plt.xscale('log')
    plt.legend()

    plt.subplot(1, 4, 2)
    plt.plot(val_loss_df['epoch'], val_loss_df['val_loss'], label='Validation Loss')
    plt.title('Validation Loss Over Epochs')
    plt.xlabel('Step')
    plt.ylabel('Loss')
    plt.xscale('log')
    plt.legend()

    plt.subplot(1, 4, 3)
    plt.plot(val_auc_df['epoch'], val_auc_df['val_auc'], label='Validation AUC')
    plt.title('Validation AUC Over Epochs')
    plt.xlabel('Step')
    plt.ylabel('AUC')
    plt.xscale('log')
    plt.legend()

    plt.subplot(1, 4, 4)
    plt.plot(learning_rate_df['epoch'], learning_rate_df['learning_rate'], label='Learning Rate')
    plt.title('Learning Rate Over Epochs')
    plt.xlabel('Step')
    plt.ylabel('Learning Rate')
    plt.xscale('log')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
base_path = 'lightning_logs/mlp_model'
latest_dir = find_latest_directory(base_path)
plot_metrics(latest_dir, 'MLP Model')

# %% [markdown]
# ## Interaction Network

# %% [markdown]
# So we're struggling to beat the BDT - it's just too good at consuming tabular data. But we have a secret weapon: the graph structure! Let's try a simple graph convolution network. We will use the industry-standard PyG ("Pytorch Geometric") library for this, with its built-in GCN implementation. But first, let's try to code up a graph neural network from scratch.

# %%
import torch
from torch_scatter import scatter_mean, scatter_add
from torch import nn

class InteractionGNN(BaseLitModel):
    def __init__(self, hparams):
        super(InteractionGNN, self).__init__(lr=hparams['lr'], weight_decay=hparams['weight_decay'], lr_decay=hparams['lr_decay'])

        # Node and Edge Networks
        self.input_node_network = make_mlp(
            input_size=hparams['input_size'],
            sizes=[hparams['hidden_size']] * 2,
            layer_norm=True,
            hidden_activation="ReLU"
        )
        self.node_network = make_mlp(
            input_size=hparams['hidden_size'],
            sizes=[hparams['hidden_size']] * 2,
            layer_norm=True,
            hidden_activation="ReLU"
        )
        self.edge_network = make_mlp(
            input_size=2 * hparams['hidden_size'],
            sizes=[hparams['hidden_size']] * 2,
            layer_norm=True,
            hidden_activation="ReLU"
        )
        self.output_network = make_mlp(
            input_size=hparams['hidden_size'],
            sizes=[hparams['output_size']],
            layer_norm=True,
            hidden_activation="ReLU",
            output_activation="Sigmoid"
        )
        self.num_graph_iters = hparams['num_graph_iters']

        self.aggregation = scatter_add

    def forward(self, graph):
        x, edge_index = graph.x.float(), graph.edge_index
        start, end = edge_index
        x = self.input_node_network(x)

        for _ in range(self.num_graph_iters):
            # Save the input to the iteration for the skip connection
            x_skip = x

            # Edge features update
            e = self.message_passing(x, start, end)

            # Message passing
            x = self.aggregation(e, end, dim=0, dim_size=x.size(0))  # Aggregating messages to target nodes

            # x = scatter_add(e, end)

            # Node features update
            x = self.node_network(x)

            # Adding skip connection
            x = x + x_skip

        # Aggregate to graph level
        x = self.aggregation(x, graph.batch, dim=0)
        
        # Output layer
        out = self.output_network(x)

        return out
    
    def message_passing(self, x, start, end):
        
        edge_features = torch.cat([x[start], x[end]], dim=1)
        e = self.edge_network(edge_features)
        return e

    def apply_model(self, batch):
        return self(batch), batch.y

# Example usage
hparams = {
    'input_size': train_pyg_loader.dataset[0].x.shape[1],
    'hidden_size': 64,
    'output_size': 1,
    'lr': 3e-4,
    'weight_decay': 1e-5,
    'lr_decay': 0.97,
    'num_graph_iters': 3  # Number of graph iterations
}
model = InteractionGNN(hparams)

# Training setup remains the same
auc_callback = AUCCallback()
csv_logger = CSVLogger('lightning_logs', name='interaction_gnn_model')
trainer = Trainer(max_epochs=50, accelerator="gpu", callbacks=[auc_callback], logger=csv_logger)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_pyg_loader, valid_pyg_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name               | Type       | Params
# --------------------------------------------------
# 0 | criterion          | BCELoss    | 0
# 1 | input_node_network | Sequential | 4.8 K
# 2 | node_network       | Sequential | 8.3 K
# 3 | edge_network       | Sequential | 12.4 K
# 4 | output_network     | Sequential | 65
# --------------------------------------------------
# 25.6 K    Trainable params
# 0         Non-trainable params
# 25.6 K    Total params
# 0.102     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 1029/1029 [00:17<00:00, 58.18it/s, v_num=2]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:01, 122.88it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 144.85it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 151.65it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 146.79it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 151.03it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 150.16it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 151.82it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 153.77it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 148.14it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 148.45it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 147.25it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 146.93it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 147.24it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 145.98it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 146.64it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 145.78it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 145.76it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 143.41it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 143.93it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 143.81it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 143.73it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 144.03it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 142.57it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 141.69it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 140.89it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 141.57it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 142.04it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 143.03it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 143.79it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 144.44it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 144.62it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 145.09it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 145.64it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 145.97it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 146.09it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 145.80it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 145.65it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 145.95it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 145.74it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 145.47it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 138.09it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 134.03it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 133.25it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 132.30it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 132.72it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 133.04it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 133.02it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 132.76it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 132.33it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 131.83it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 131.64it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 131.77it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 132.27it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 132.70it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 132.96it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 133.53it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 133.91it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 134.14it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 134.66it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 134.88it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 135.18it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 135.55it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 135.68it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 136.10it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 136.59it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 136.79it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 137.16it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 137.37it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 137.90it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 138.17it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 138.19it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 138.32it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 138.50it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 138.49it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 138.72it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 138.82it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 138.89it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 138.72it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 138.96it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 138.98it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 139.08it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 139.14it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 139.14it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 138.97it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 138.84it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 139.05it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 139.01it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 139.11it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 139.20it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 139.12it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 139.35it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 139.30it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 139.44it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 139.58it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 139.68it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 139.91it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 139.98it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 140.28it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 140.47it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 140.57it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 140.84it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 141.13it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 141.21it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 141.48it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 141.67it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 141.79it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 141.81it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 141.92it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 142.17it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 142.34it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 142.40it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 142.56it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 142.73it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 142.84it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 143.04it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 142.75it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 142.92it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 143.18it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 143.27it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 143.46it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 143.67it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 143.75it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 143.92it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 144.04it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 144.23it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 144.32it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 144.28it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 144.44it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 144.67it/s]
# Epoch 1: 100%|██████████| 1029/1029 [00:14<00:00, 71.82it/s, v_num=2, val_loss=0.145, val_auc=0.357, train_loss=0.277, learning_rate=0.0003]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 144.83it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 139.06it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 142.66it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 146.19it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 144.84it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 146.71it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 145.14it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 144.87it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 146.99it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 148.48it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 150.19it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 151.38it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 152.63it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 153.93it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 153.37it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 154.39it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 155.97it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 155.96it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 156.55it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 157.32it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 156.03it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 155.76it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 154.97it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 154.65it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 154.87it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 155.17it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 155.74it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00,
/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 119.48it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 119.89it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 120.05it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 120.18it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 120.19it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 120.35it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 120.48it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 120.68it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 120.80it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 120.92it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 121.27it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 121.42it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 121.67it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 121.97it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 122.22it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 122.47it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 122.50it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 122.82it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 123.05it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 123.19it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 123.35it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 123.32it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 123.51it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 123.62it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 123.75it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 123.92it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 124.16it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 124.36it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 124.49it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 124.73it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 124.84it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 124.99it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 125.23it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 125.26it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 125.46it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 125.61it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 125.83it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 126.02it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 126.24it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 126.55it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 126.73it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 126.97it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 127.24it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 127.41it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 127.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 127.80it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 127.90it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 128.21it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 128.45it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:01<00:00, 128.72it/s]
# Epoch 49: 100%|██████████| 1029/1029 [00:14<00:00, 71.22it/s, v_num=2, val_loss=0.0841, val_auc=0.737, train_loss=0.111, learning_rate=6.95e-5]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 160.46it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 161.90it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 163.16it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 161.24it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 161.15it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 160.17it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 159.86it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 157.08it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 157.43it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 157.30it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 157.28it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 157.84it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 158.37it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 158.97it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 159.55it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 157.86it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 158.38it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 158.61it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 158.11it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 157.39it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 156.45it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 152.50it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 142.29it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 141.18it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 137.02it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 135.99it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 134.40it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 133.91it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 134.81it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 135.52it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 136.10it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 136.53it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 136.75it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 136.92it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 137.12it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 137.47it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 137.88it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 137.96it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 138.03it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 138.35it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 138.65it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 138.39it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 138.77it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 138.93it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 139.22it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 139.45it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 139.49it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 139.59it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 139.88it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 139.69it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 139.88it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 140.05it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 140.34it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 140.58it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 140.79it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 140.78it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 141.01it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 141.24it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 141.41it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 141.58it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 141.33it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 141.41it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 141.37it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 141.30it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 141.42it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 141.52it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 141.64it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 141.73it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 140.70it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 139.63it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 139.43it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 139.40it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 139.47it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 139.60it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 139.73it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 139.74it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 139.84it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 139.68it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 139.84it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 139.99it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 134.94it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 134.43it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 133.87it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 133.05it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 132.78it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 132.99it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 132.99it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 132.93it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 132.66it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 132.68it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 132.78it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 132.96it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 132.84it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 132.96it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 133.20it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 133.38it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 133.51it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 133.76it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 134.02it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 134.24it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 134.29it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 134.52it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 134.76it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 135.00it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 135.24it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 135.47it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 135.52it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 135.73it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 135.82it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 135.36it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 135.19it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 135.20it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 135.37it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 135.41it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 135.39it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 135.56it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 135.73it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 135.81it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 135.92it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 135.86it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 135.80it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 135.94it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 136.02it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 136.12it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 136.28it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 136.35it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 136.51it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 136.60it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 136.82it/s]
# Epoch 49: 100%|██████████| 1029/1029 [00:15<00:00, 66.80it/s, v_num=2, val_loss=0.0779, val_auc=0.779, train_loss=0.110, learning_rate=6.74e-5]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 1029/1029 [00:15<00:00, 66.76it/s, v_num=2, val_loss=0.0779, val_auc=0.779, train_loss=0.110, learning_rate=6.74e-5]

# %%
base_path = 'lightning_logs/interaction_gnn_model'
latest_dir = find_latest_directory(base_path)
plot_metrics(latest_dir, 'Interaction GNN Model')

# %%
# Test the model
trainer.test(model, test_pyg_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|██████████| 129/129 [00:01<00:00, 94.49it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_auc          │     0.750288724899292     │
# │         test_loss         │    0.12033267319202423    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.12033267319202423, 'test_auc': 0.750288724899292}]

# %%
from ogb.graphproppred import Evaluator

evaluator = Evaluator(name = 'ogbg-molhiv')

y_true = torch.cat([graph.y for graph in valid_pyg_loader]).numpy()
with torch.no_grad():
    y_pred = torch.cat([model(graph) for graph in valid_pyg_loader]).numpy()
input_dict = {"y_true": y_true, "y_pred": y_pred}
result_dict = evaluator.eval(input_dict)
print("VALIDATION RESULTS", result_dict)
# Out:
# VALIDATION RESULTS {'rocauc': 0.7790790956300216}

# %%
from ogb.graphproppred import Evaluator

evaluator = Evaluator(name = 'ogbg-molhiv')

y_true = torch.cat([graph.y for graph in test_pyg_loader]).numpy()
with torch.no_grad():
    y_pred = torch.cat([model(graph) for graph in test_pyg_loader]).numpy()
input_dict = {"y_true": y_true, "y_pred": y_pred}
result_dict = evaluator.eval(input_dict)
print("TEST RESULTS", result_dict)
# Out:
# TEST RESULTS {'rocauc': 0.7502887270901332}

# %% [markdown]
# # Try your own Torch Geometric model!

# %% [markdown]
# ## Play with convolution and aggregation styles

# %% [markdown]
# We can tweak the convolution and aggregation styles to see if we can improve the performance of our model. E.g. we can try scatter max, scatter std, combine scatter operations, or we can try the MANY different convolutions available in PyG.

# %% [markdown]
# ## We can also try out-of-the-box convolutions from Pytorch Geometric

# %% [markdown]
# ### Try a simple graph convolution network

# %%
import lightning as lit
from lightning.pytorch.callbacks import Callback
from lightning.pytorch import Trainer
from torch.utils.data import TensorDataset, DataLoader
import torch
from torch import nn
from torch_geometric.nn import GCNConv, aggr
from lightning.pytorch.loggers import CSVLogger  # Import CSVLogger
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

class GCN(BaseLitModel):
    def __init__(self, input_size, hidden_size, output_size):
        super(GCN, self).__init__(lr=1e-3, weight_decay=0, lr_decay=0.90)
        self.node_network_1 = make_mlp(input_size, [hidden_size]*2, layer_norm=True, hidden_activation="ReLU")
        self.conv = GCNConv(hidden_size, hidden_size)
        self.node_network_2 = make_mlp(hidden_size, [hidden_size]*2, layer_norm=True, hidden_activation="ReLU")
        self.output_network = make_mlp(hidden_size, [output_size], layer_norm=True, hidden_activation="ReLU", output_activation="Sigmoid")
        self.aggregation = aggr.MeanAggregation()

    def forward(self, graph):
        x = self.node_network_1(graph.x.float())
        x = self.conv(x, graph.edge_index)
        x = self.node_network_2(x)
        x = self.aggregation(x, graph.batch)
        return self.output_network(x)

    def apply_model(self, batch):
        return self(batch), batch.y

# Initialize the model
input_size = train_pyg_loader.dataset[0].x.shape[1]
hidden_size = 64  # You can tune this parameter
output_size = 1
model = GCN(input_size, hidden_size, output_size)

# Train the model
auc_callback = AUCCallback()
csv_logger = CSVLogger('lightning_logs', name='gcn_model')  # Initialize CSVLogger
trainer = Trainer(max_epochs=10, accelerator="gpu", callbacks=[auc_callback], logger=csv_logger)  # Add logger to Trainer
trainer.fit(model, train_pyg_loader, valid_pyg_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: lightning_logs/gcn_model
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type            | Params
# ---------------------------------------------------
# 0 | criterion      | BCELoss         | 0
# 1 | node_network_1 | Sequential      | 4.8 K
# 2 | conv           | GCNConv         | 4.2 K
# 3 | node_network_2 | Sequential      | 8.3 K
# 4 | output_network | Sequential      | 65
# 5 | aggregation    | MeanAggregation | 0
# ---------------------------------------------------
# 17.3 K    Trainable params
# 0         Non-trainable params
# 17.3 K    Total params
# 0.069     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 1029/1029 [00:13<00:00, 74.69it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 225.99it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 190.53it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 162.76it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 161.24it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 152.01it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 148.87it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 146.49it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 144.91it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 144.86it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 142.81it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 143.19it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 141.62it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 142.03it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 141.55it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 141.29it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 141.72it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 141.34it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 141.34it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 140.72it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 141.29it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 138.36it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 139.49it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 139.46it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 139.61it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 138.23it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 138.27it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 139.37it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 139.02it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 139.55it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 140.03it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 140.18it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 140.91it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 140.79it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 141.64it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 142.15it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 142.43it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 142.41it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 142.30it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 142.82it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 143.15it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 143.38it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 143.76it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 143.83it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 143.68it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 143.63it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 142.41it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 141.39it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 141.04it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 140.71it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 140.98it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 141.58it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 141.83it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 142.17it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 142.06it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 142.24it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 142.83it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 142.58it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 142.97it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 142.86it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 142.85it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 143.26it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 142.96it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 143.49it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 143.30it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 143.52it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 144.01it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 143.89it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 144.23it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 144.47it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 144.73it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 145.08it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 144.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 145.21it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 145.57it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 145.26it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 145.52it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 145.23it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 145.52it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 145.91it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 145.72it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 146.13it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 146.32it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 145.90it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 145.89it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 145.71it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 145.77it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 145.50it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 145.63it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 145.67it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 145.25it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 145.63it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 145.60it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 145.83it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 145.98it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 145.95it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 146.11it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 145.90it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 146.19it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 146.18it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 146.01it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 146.25it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 146.08it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 146.16it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 146.19it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 146.29it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 146.53it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 146.50it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 146.72it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 147.05it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 146.90it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 147.09it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 147.28it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 147.24it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 147.37it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 147.29it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 147.43it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 147.60it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 147.55it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 147.74it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 147.59it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 147.58it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 147.42it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 147.46it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 147.66it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 147.67it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 147.73it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 147.94it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 147.89it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 148.21it/s]
# Epoch 1: 100%|██████████| 1029/1029 [00:10<00:00, 95.88it/s, v_num=0, val_loss=0.0984, val_auc=0.575, train_loss=0.162, learning_rate=0.001]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:01, 117.79it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:01, 109.09it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:01, 101.57it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:01, 106.01it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:01, 110.38it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:01, 116.82it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:01, 121.94it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 125.28it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 128.12it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 130.74it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 132.50it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 130.84it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 133.14it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 131.91it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 132.11it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 131.66it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 131.33it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 132.04it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 131.50it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 132.08it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 130.57it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 130.45it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 130.51it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 131.32it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 132.05it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 132.33it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 132.00it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 132.14it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 133.15it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 132.87it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 133.53it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 134.22it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 134.56it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 135.47it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 135.27it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 135.88it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 136.29it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 136.05it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 135.79it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 135.29it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 135.25it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 135.25it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 135.05it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 135.49it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 136.10it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 136.36it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 136.73it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 137.29it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 137.74it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 138.21it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 138.47it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 138.71it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 139.09it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 138.67it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 138.55it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 138.56it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 138.05it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 137.77it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 137.63it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 137.69it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 137.45it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 137.52it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 137.27it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 137.63it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 137.65it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 137.85it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 137.91it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 137.81it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 138.16it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 138.43it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 138.37it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 138.32it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 137.94it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 137.87it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 138.13it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 138.37it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 138.66it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 138.58it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 138.62it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 138.93it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 139.36it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 139.68it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 139.87it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 140.14it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 140.51it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 140.78it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 141.05it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00,
/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 135.31it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 144.85it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 139.93it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 135.65it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 133.86it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 135.73it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 132.57it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 133.47it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 135.62it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 135.53it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 136.95it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 134.26it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 132.56it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 131.69it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 132.73it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 133.17it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 136.29it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 135.83it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 137.19it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 138.46it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 138.89it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 139.90it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 139.66it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 140.37it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 141.26it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 140.62it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 141.40it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 140.34it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 140.54it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 139.77it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 140.50it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 141.30it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 141.06it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 141.63it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 141.55it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 141.89it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 142.48it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 142.12it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 142.59it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 142.64it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 142.86it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 141.20it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 134.23it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 132.83it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 131.77it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 130.24it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 127.90it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 127.52it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 127.19it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 126.65it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 127.17it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 127.60it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 127.49it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 128.18it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 127.51it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 127.19it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 126.86it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 126.69it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 126.43it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 126.80it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 127.04it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 127.26it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 127.65it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 127.72it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 127.93it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 127.59it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 128.03it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 128.35it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 128.55it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 129.07it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 129.16it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 129.23it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 129.16it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 129.48it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 129.52it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 129.66it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 129.72it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 129.77it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 129.97it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 130.08it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 130.30it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 130.12it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 130.29it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 130.60it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 130.69it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 130.91it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 130.89it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 131.12it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 131.24it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 131.35it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 131.63it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 131.50it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 131.81it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 131.37it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 131.61it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 131.85it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 131.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 132.22it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 132.00it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 132.32it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 132.42it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 132.56it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 132.84it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 132.89it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 133.13it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 132.86it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 132.98it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 133.13it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 133.04it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 133.22it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 133.11it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 133.24it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 133.11it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 133.34it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 133.65it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 133.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 133.93it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 133.97it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 134.07it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 134.21it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 133.37it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 133.19it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 133.22it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 133.01it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 133.00it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 132.87it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 132.87it/s]
# Epoch 9: 100%|██████████| 1029/1029 [00:11<00:00, 85.83it/s, v_num=0, val_loss=0.0954, val_auc=0.642, train_loss=0.154, learning_rate=0.000387]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 1029/1029 [00:11<00:00, 85.77it/s, v_num=0, val_loss=0.0954, val_auc=0.642, train_loss=0.154, learning_rate=0.000387]

# %%
base_path = 'lightning_logs/gcn_model'
latest_dir = find_latest_directory(base_path)
plot_metrics(latest_dir, 'GCN Model')

# %% [markdown]
# ### Test graph attention network

# %%
from torch_geometric.nn import GATv2Conv

class GAT(BaseLitModel):
    def __init__(self, input_size, hidden_size, output_size):
        super(GAT, self).__init__(lr=1e-3, weight_decay=0, lr_decay=0.90)
        self.node_network_1 = make_mlp(input_size, [hidden_size]*2, layer_norm=True, hidden_activation="ReLU")
        self.conv = GATv2Conv(hidden_size, hidden_size, heads=1)
        self.node_network_2 = make_mlp(hidden_size, [hidden_size]*2, layer_norm=True, hidden_activation="ReLU")
        self.output_network = make_mlp(hidden_size, [output_size], layer_norm=True, hidden_activation="ReLU", output_activation="Sigmoid")
        self.aggregation = aggr.MeanAggregation()

    def forward(self, graph):
        x = self.node_network_1(graph.x.float())
        x = self.conv(x, graph.edge_index)
        x = self.node_network_2(x)
        x = self.aggregation(x, graph.batch)
        return self.output_network(x)

    def apply_model(self, batch):
        return self(batch), batch.y

# Initialize the model
input_size = train_pyg_loader.dataset[0].x.shape[1]
hidden_size = 64  # You can tune this parameter
output_size = 1
model = GAT(input_size, hidden_size, output_size)

# Train the model
auc_callback = AUCCallback()
csv_logger = CSVLogger('lightning_logs', name='gat_model')  # Initialize CSVLogger
trainer = Trainer(max_epochs=10, accelerator="gpu", callbacks=[auc_callback], logger=csv_logger)  # Add logger to Trainer
trainer.fit(model, train_pyg_loader, valid_pyg_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: lightning_logs/gat_model
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type            | Params
# ---------------------------------------------------
# 0 | criterion      | BCELoss         | 0
# 1 | node_network_1 | Sequential      | 4.8 K
# 2 | conv           | GATv2Conv       | 8.4 K
# 3 | node_network_2 | Sequential      | 8.3 K
# 4 | output_network | Sequential      | 65
# 5 | aggregation    | MeanAggregation | 0
# ---------------------------------------------------
# 21.6 K    Trainable params
# 0         Non-trainable params
# 21.6 K    Total params
# 0.087     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/ali/miniconda3/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 1029/1029 [00:14<00:00, 70.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:01, 90.66it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:01, 95.20it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:01, 103.15it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:01, 108.66it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:01, 110.18it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:01, 113.10it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:01, 114.77it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:01, 113.22it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:01, 112.37it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:01, 112.93it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:01, 108.83it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:01, 106.33it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:01, 106.50it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:01, 107.20it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:01, 108.45it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:01, 109.79it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:01, 110.55it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 111.24it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 112.20it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 112.99it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 113.47it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 115.32it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 116.03it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 117.17it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 118.29it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 118.61it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 119.68it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 119.49it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 120.32it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 120.98it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 121.62it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 122.50it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 123.19it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 124.31it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 125.10it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 125.53it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 125.95it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 126.52it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 127.11it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 127.66it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 128.29it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 128.93it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 129.12it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 129.90it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 130.57it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 130.93it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 131.65it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 132.01it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 131.56it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 131.41it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 131.53it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 131.81it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 131.62it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 131.89it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 131.42it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 131.75it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 131.50it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 132.03it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 131.84it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 132.18it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 131.98it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 132.24it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 132.26it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 132.51it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 132.89it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 132.84it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 133.06it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 133.06it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 132.99it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 133.13it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 132.73it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 133.19it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 133.20it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 133.58it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 133.93it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 133.57it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 133.49it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 133.76it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 134.23it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 133.99it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 134.00it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 133.71it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 133.83it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 133.66it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 133.56it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 133.48it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 133.45it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 133.61it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 133.37it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 133.49it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 133.33it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 133.58it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 133.44it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 133.55it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 133.60it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 133.63it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 133.68it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 133.77it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 134.11it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 134.07it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 134.43it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 134.63it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 134.82it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 134.69it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 134.88it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 134.29it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 134.58it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 134.59it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 134.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 134.45it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 134.58it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 134.45it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 134.62it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 134.93it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 134.73it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 134.94it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 134.84it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 135.07it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 135.09it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 135.03it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 135.03it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 134.87it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 134.85it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 134.76it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 134.92it/s]
# Epoch 1: 100%|██████████| 1029/1029 [00:12<00:00, 84.53it/s, v_num=0, val_loss=0.110, val_auc=0.608, train_loss=0.162, learning_rate=0.001]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 177.51it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 146.47it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 146.50it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:00, 134.01it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:00, 128.70it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:00, 125.55it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:00, 128.99it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:00, 130.10it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:00, 132.16it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:00, 134.88it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:00, 134.14it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:00, 136.15it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:00, 135.22it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:00, 136.77it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:00, 138.26it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:00, 138.30it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:00, 139.59it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:00, 138.53it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:00, 139.92it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:00, 137.04it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 138.06it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 138.51it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 138.82it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 140.14it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 139.48it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 140.61it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 141.21it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 140.52it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 140.87it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 140.36it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 140.55it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 139.71it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 140.43it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 140.75it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 140.63it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 141.24it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 141.10it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 141.50it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 141.89it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 141.60it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 142.17it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00,
/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 133.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 133.57it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 133.52it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 133.52it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 133.46it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 133.63it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 133.71it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 133.89it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 133.80it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 133.85it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 133.82it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 134.07it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 134.22it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 134.14it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 134.03it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 134.27it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 134.12it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 134.31it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 134.37it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 134.24it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 134.34it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 134.16it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 134.43it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 134.31it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 134.24it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 133.94it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 134.09it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 134.17it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 134.36it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 134.50it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 134.44it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 134.65it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 134.82it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 134.83it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 134.98it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 134.91it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 135.06it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 135.16it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 135.32it/s]
# Epoch 9: 100%|██████████| 1029/1029 [00:12<00:00, 83.93it/s, v_num=0, val_loss=0.0929, val_auc=0.656, train_loss=0.152, learning_rate=0.00043]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/129 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/129 [00:00<00:00, 174.64it/s]
# Validation DataLoader 0:   2%|▏         | 2/129 [00:00<00:00, 141.22it/s]
# Validation DataLoader 0:   2%|▏         | 3/129 [00:00<00:00, 142.52it/s]
# Validation DataLoader 0:   3%|▎         | 4/129 [00:00<00:01, 121.03it/s]
# Validation DataLoader 0:   4%|▍         | 5/129 [00:00<00:01, 108.70it/s]
# Validation DataLoader 0:   5%|▍         | 6/129 [00:00<00:01, 104.13it/s]
# Validation DataLoader 0:   5%|▌         | 7/129 [00:00<00:01, 101.31it/s]
# Validation DataLoader 0:   6%|▌         | 8/129 [00:00<00:01, 93.67it/s]
# Validation DataLoader 0:   7%|▋         | 9/129 [00:00<00:01, 94.29it/s]
# Validation DataLoader 0:   8%|▊         | 10/129 [00:00<00:01, 98.05it/s]
# Validation DataLoader 0:   9%|▊         | 11/129 [00:00<00:01, 97.91it/s]
# Validation DataLoader 0:   9%|▉         | 12/129 [00:00<00:01, 101.73it/s]
# Validation DataLoader 0:  10%|█         | 13/129 [00:00<00:01, 102.04it/s]
# Validation DataLoader 0:  11%|█         | 14/129 [00:00<00:01, 103.45it/s]
# Validation DataLoader 0:  12%|█▏        | 15/129 [00:00<00:01, 104.31it/s]
# Validation DataLoader 0:  12%|█▏        | 16/129 [00:00<00:01, 105.84it/s]
# Validation DataLoader 0:  13%|█▎        | 17/129 [00:00<00:01, 105.27it/s]
# Validation DataLoader 0:  14%|█▍        | 18/129 [00:00<00:01, 106.41it/s]
# Validation DataLoader 0:  15%|█▍        | 19/129 [00:00<00:01, 106.28it/s]
# Validation DataLoader 0:  16%|█▌        | 20/129 [00:00<00:01, 108.23it/s]
# Validation DataLoader 0:  16%|█▋        | 21/129 [00:00<00:00, 109.42it/s]
# Validation DataLoader 0:  17%|█▋        | 22/129 [00:00<00:00, 110.66it/s]
# Validation DataLoader 0:  18%|█▊        | 23/129 [00:00<00:00, 112.36it/s]
# Validation DataLoader 0:  19%|█▊        | 24/129 [00:00<00:00, 113.02it/s]
# Validation DataLoader 0:  19%|█▉        | 25/129 [00:00<00:00, 114.84it/s]
# Validation DataLoader 0:  20%|██        | 26/129 [00:00<00:00, 115.90it/s]
# Validation DataLoader 0:  21%|██        | 27/129 [00:00<00:00, 117.17it/s]
# Validation DataLoader 0:  22%|██▏       | 28/129 [00:00<00:00, 118.46it/s]
# Validation DataLoader 0:  22%|██▏       | 29/129 [00:00<00:00, 118.81it/s]
# Validation DataLoader 0:  23%|██▎       | 30/129 [00:00<00:00, 119.97it/s]
# Validation DataLoader 0:  24%|██▍       | 31/129 [00:00<00:00, 121.06it/s]
# Validation DataLoader 0:  25%|██▍       | 32/129 [00:00<00:00, 121.60it/s]
# Validation DataLoader 0:  26%|██▌       | 33/129 [00:00<00:00, 121.76it/s]
# Validation DataLoader 0:  26%|██▋       | 34/129 [00:00<00:00, 121.75it/s]
# Validation DataLoader 0:  27%|██▋       | 35/129 [00:00<00:00, 122.64it/s]
# Validation DataLoader 0:  28%|██▊       | 36/129 [00:00<00:00, 123.39it/s]
# Validation DataLoader 0:  29%|██▊       | 37/129 [00:00<00:00, 124.28it/s]
# Validation DataLoader 0:  29%|██▉       | 38/129 [00:00<00:00, 125.10it/s]
# Validation DataLoader 0:  30%|███       | 39/129 [00:00<00:00, 125.65it/s]
# Validation DataLoader 0:  31%|███       | 40/129 [00:00<00:00, 126.49it/s]
# Validation DataLoader 0:  32%|███▏      | 41/129 [00:00<00:00, 127.14it/s]
# Validation DataLoader 0:  33%|███▎      | 42/129 [00:00<00:00, 127.61it/s]
# Validation DataLoader 0:  33%|███▎      | 43/129 [00:00<00:00, 128.08it/s]
# Validation DataLoader 0:  34%|███▍      | 44/129 [00:00<00:00, 127.22it/s]
# Validation DataLoader 0:  35%|███▍      | 45/129 [00:00<00:00, 126.93it/s]
# Validation DataLoader 0:  36%|███▌      | 46/129 [00:00<00:00, 127.05it/s]
# Validation DataLoader 0:  36%|███▋      | 47/129 [00:00<00:00, 127.10it/s]
# Validation DataLoader 0:  37%|███▋      | 48/129 [00:00<00:00, 127.20it/s]
# Validation DataLoader 0:  38%|███▊      | 49/129 [00:00<00:00, 127.32it/s]
# Validation DataLoader 0:  39%|███▉      | 50/129 [00:00<00:00, 127.60it/s]
# Validation DataLoader 0:  40%|███▉      | 51/129 [00:00<00:00, 127.49it/s]
# Validation DataLoader 0:  40%|████      | 52/129 [00:00<00:00, 127.81it/s]
# Validation DataLoader 0:  41%|████      | 53/129 [00:00<00:00, 127.75it/s]
# Validation DataLoader 0:  42%|████▏     | 54/129 [00:00<00:00, 128.29it/s]
# Validation DataLoader 0:  43%|████▎     | 55/129 [00:00<00:00, 128.48it/s]
# Validation DataLoader 0:  43%|████▎     | 56/129 [00:00<00:00, 129.06it/s]
# Validation DataLoader 0:  44%|████▍     | 57/129 [00:00<00:00, 129.23it/s]
# Validation DataLoader 0:  45%|████▍     | 58/129 [00:00<00:00, 129.49it/s]
# Validation DataLoader 0:  46%|████▌     | 59/129 [00:00<00:00, 130.08it/s]
# Validation DataLoader 0:  47%|████▋     | 60/129 [00:00<00:00, 130.27it/s]
# Validation DataLoader 0:  47%|████▋     | 61/129 [00:00<00:00, 130.42it/s]
# Validation DataLoader 0:  48%|████▊     | 62/129 [00:00<00:00, 130.53it/s]
# Validation DataLoader 0:  49%|████▉     | 63/129 [00:00<00:00, 130.85it/s]
# Validation DataLoader 0:  50%|████▉     | 64/129 [00:00<00:00, 131.33it/s]
# Validation DataLoader 0:  50%|█████     | 65/129 [00:00<00:00, 131.34it/s]
# Validation DataLoader 0:  51%|█████     | 66/129 [00:00<00:00, 131.54it/s]
# Validation DataLoader 0:  52%|█████▏    | 67/129 [00:00<00:00, 131.06it/s]
# Validation DataLoader 0:  53%|█████▎    | 68/129 [00:00<00:00, 131.00it/s]
# Validation DataLoader 0:  53%|█████▎    | 69/129 [00:00<00:00, 130.97it/s]
# Validation DataLoader 0:  54%|█████▍    | 70/129 [00:00<00:00, 130.27it/s]
# Validation DataLoader 0:  55%|█████▌    | 71/129 [00:00<00:00, 129.94it/s]
# Validation DataLoader 0:  56%|█████▌    | 72/129 [00:00<00:00, 130.23it/s]
# Validation DataLoader 0:  57%|█████▋    | 73/129 [00:00<00:00, 130.01it/s]
# Validation DataLoader 0:  57%|█████▋    | 74/129 [00:00<00:00, 130.42it/s]
# Validation DataLoader 0:  58%|█████▊    | 75/129 [00:00<00:00, 130.42it/s]
# Validation DataLoader 0:  59%|█████▉    | 76/129 [00:00<00:00, 130.57it/s]
# Validation DataLoader 0:  60%|█████▉    | 77/129 [00:00<00:00, 130.35it/s]
# Validation DataLoader 0:  60%|██████    | 78/129 [00:00<00:00, 130.30it/s]
# Validation DataLoader 0:  61%|██████    | 79/129 [00:00<00:00, 130.34it/s]
# Validation DataLoader 0:  62%|██████▏   | 80/129 [00:00<00:00, 130.29it/s]
# Validation DataLoader 0:  63%|██████▎   | 81/129 [00:00<00:00, 130.54it/s]
# Validation DataLoader 0:  64%|██████▎   | 82/129 [00:00<00:00, 130.53it/s]
# Validation DataLoader 0:  64%|██████▍   | 83/129 [00:00<00:00, 130.64it/s]
# Validation DataLoader 0:  65%|██████▌   | 84/129 [00:00<00:00, 130.43it/s]
# Validation DataLoader 0:  66%|██████▌   | 85/129 [00:00<00:00, 130.62it/s]
# Validation DataLoader 0:  67%|██████▋   | 86/129 [00:00<00:00, 130.79it/s]
# Validation DataLoader 0:  67%|██████▋   | 87/129 [00:00<00:00, 130.86it/s]
# Validation DataLoader 0:  68%|██████▊   | 88/129 [00:00<00:00, 131.07it/s]
# Validation DataLoader 0:  69%|██████▉   | 89/129 [00:00<00:00, 130.94it/s]
# Validation DataLoader 0:  70%|██████▉   | 90/129 [00:00<00:00, 131.11it/s]
# Validation DataLoader 0:  71%|███████   | 91/129 [00:00<00:00, 131.19it/s]
# Validation DataLoader 0:  71%|███████▏  | 92/129 [00:00<00:00, 131.23it/s]
# Validation DataLoader 0:  72%|███████▏  | 93/129 [00:00<00:00, 131.16it/s]
# Validation DataLoader 0:  73%|███████▎  | 94/129 [00:00<00:00, 131.17it/s]
# Validation DataLoader 0:  74%|███████▎  | 95/129 [00:00<00:00, 131.39it/s]
# Validation DataLoader 0:  74%|███████▍  | 96/129 [00:00<00:00, 131.21it/s]
# Validation DataLoader 0:  75%|███████▌  | 97/129 [00:00<00:00, 130.74it/s]
# Validation DataLoader 0:  76%|███████▌  | 98/129 [00:00<00:00, 130.85it/s]
# Validation DataLoader 0:  77%|███████▋  | 99/129 [00:00<00:00, 130.98it/s]
# Validation DataLoader 0:  78%|███████▊  | 100/129 [00:00<00:00, 130.92it/s]
# Validation DataLoader 0:  78%|███████▊  | 101/129 [00:00<00:00, 131.11it/s]
# Validation DataLoader 0:  79%|███████▉  | 102/129 [00:00<00:00, 131.06it/s]
# Validation DataLoader 0:  80%|███████▉  | 103/129 [00:00<00:00, 131.35it/s]
# Validation DataLoader 0:  81%|████████  | 104/129 [00:00<00:00, 131.60it/s]
# Validation DataLoader 0:  81%|████████▏ | 105/129 [00:00<00:00, 131.61it/s]
# Validation DataLoader 0:  82%|████████▏ | 106/129 [00:00<00:00, 131.86it/s]
# Validation DataLoader 0:  83%|████████▎ | 107/129 [00:00<00:00, 131.76it/s]
# Validation DataLoader 0:  84%|████████▎ | 108/129 [00:00<00:00, 132.03it/s]
# Validation DataLoader 0:  84%|████████▍ | 109/129 [00:00<00:00, 131.93it/s]
# Validation DataLoader 0:  85%|████████▌ | 110/129 [00:00<00:00, 132.12it/s]
# Validation DataLoader 0:  86%|████████▌ | 111/129 [00:00<00:00, 132.29it/s]
# Validation DataLoader 0:  87%|████████▋ | 112/129 [00:00<00:00, 132.32it/s]
# Validation DataLoader 0:  88%|████████▊ | 113/129 [00:00<00:00, 132.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 114/129 [00:00<00:00, 132.46it/s]
# Validation DataLoader 0:  89%|████████▉ | 115/129 [00:00<00:00, 132.67it/s]
# Validation DataLoader 0:  90%|████████▉ | 116/129 [00:00<00:00, 132.74it/s]
# Validation DataLoader 0:  91%|█████████ | 117/129 [00:00<00:00, 132.80it/s]
# Validation DataLoader 0:  91%|█████████▏| 118/129 [00:00<00:00, 133.05it/s]
# Validation DataLoader 0:  92%|█████████▏| 119/129 [00:00<00:00, 132.92it/s]
# Validation DataLoader 0:  93%|█████████▎| 120/129 [00:00<00:00, 132.96it/s]
# Validation DataLoader 0:  94%|█████████▍| 121/129 [00:00<00:00, 132.88it/s]
# Validation DataLoader 0:  95%|█████████▍| 122/129 [00:00<00:00, 133.05it/s]
# Validation DataLoader 0:  95%|█████████▌| 123/129 [00:00<00:00, 132.60it/s]
# Validation DataLoader 0:  96%|█████████▌| 124/129 [00:00<00:00, 132.65it/s]
# Validation DataLoader 0:  97%|█████████▋| 125/129 [00:00<00:00, 132.46it/s]
# Validation DataLoader 0:  98%|█████████▊| 126/129 [00:00<00:00, 132.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 127/129 [00:00<00:00, 132.40it/s]
# Validation DataLoader 0:  99%|█████████▉| 128/129 [00:00<00:00, 132.43it/s]
# Validation DataLoader 0: 100%|██████████| 129/129 [00:00<00:00, 132.57it/s]
# Epoch 9: 100%|██████████| 1029/1029 [00:13<00:00, 77.66it/s, v_num=0, val_loss=0.0916, val_auc=0.671, train_loss=0.152, learning_rate=0.000387]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 1029/1029 [00:13<00:00, 77.61it/s, v_num=0, val_loss=0.0916, val_auc=0.671, train_loss=0.152, learning_rate=0.000387]

# %%
base_path = 'lightning_logs/gat_model'
latest_dir = find_latest_directory(base_path)
plot_metrics(latest_dir, 'GAT Model')
